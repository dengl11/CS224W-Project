# %% [markdown]
# # GTD Inspector

# %%
""" Style """
import warnings
warnings.filterwarnings("ignore")  # suppres all warnings


""" Autoload """
# %load_ext autoreload
# %autoreload 2

# %%
""" Backend """
import numpy as np
from inspector_backend import *
# Out:
# Data Imported: (170350, 135)

# %%
cols = list(df.keys())
cols.sort()
cols
# Out:
# ['INT_ANY',
#  'INT_IDEO',
#  'INT_LOG',
#  'INT_MISC',
#  'addnotes',
#  'alternative',
#  'alternative_txt',
#  'approxdate',
#  'attacktype1',
#  'attacktype1_txt',
#  'attacktype2',
#  'attacktype2_txt',
#  'attacktype3',
#  'attacktype3_txt',
#  'city',
#  'claim2',
#  'claim3',
#  'claimed',
#  'claimmode',
#  'claimmode2',
#  'claimmode2_txt',
#  'claimmode3',
#  'claimmode3_txt',
#  'claimmode_txt',
#  'compclaim',
#  'corp1',
#  'corp2',
#  'corp3',
#  'country',
#  'country_txt',
#  'crit1',
#  'crit2',
#  'crit3',
#  'dbsource',
#  'divert',
#  'doubtterr',
#  'eventid',
#  'extended',
#  'gname',
#  'gname2',
#  'gname3',
#  'gsubname',
#  'gsubname2',
#  'gsubname3',
#  'guncertain1',
#  'guncertain2',
#  'guncertain3',
#  'hostkidoutcome',
#  'hostkidoutcome_txt',
#  'iday',
#  'imonth',
#  'individual',
#  'ishostkid',
#  'iyear',
#  'kidhijcountry',
#  'latitude',
#  'location',
#  'longitude',
#  'motive',
#  'multiple',
#  'natlty1',
#  'natlty1_txt',
#  'natlty2',
#  'natlty2_txt',
#  'natlty3',
#  'natlty3_txt',
#  'ndays',
#  'nhostkid',
#  'nhostkidus',
#  'nhours',
#  'nkill',
#  'nkillter',
#  'nkillus',
#  'nperpcap',
#  'nperps',
#  'nreleased',
#  'nwound',
#  'nwoundte',
#  'nwoundus',
#  'propcomment',
#  'property',
#  'propextent',
#  'propextent_txt',
#  'propvalue',
#  'provstate',
#  'ransom',
#  'ransomamt',
#  'ransomamtus',
#  'ransomnote',
#  'ransompaid',
#  'ransompaidus',
#  'region',
#  'region_txt',
#  'related',
#  'resolution',
#  'scite1',
#  'scite2',
#  'scite3',
#  'specificity',
#  'success',
#  'suicide',
#  'summary',
#  'target1',
#  'target2',
#  'target3',
#  'targsubtype1',
#  'targsubtype1_txt',
#  'targsubtype2',
#  'targsubtype2_txt',
#  'targsubtype3',
#  'targsubtype3_txt',
#  'targtype1',
#  'targtype1_txt',
#  'targtype2',
#  'targtype2_txt',
#  'targtype3',
#  'targtype3_txt',
#  'vicinity',
#  'weapdetail',
#  'weapsubtype1',
#  'weapsubtype1_txt',
#  'weapsubtype2',
#  'weapsubtype2_txt',
#  'weapsubtype3',
#  'weapsubtype3_txt',
#  'weapsubtype4',
#  'weapsubtype4_txt',
#  'weaptype1',
#  'weaptype1_txt',
#  'weaptype2',
#  'weaptype2_txt',
#  'weaptype3',
#  'weaptype3_txt',
#  'weaptype4',
#  'weaptype4_txt']

# %%
df.T.head(200)
# Out:
#                                          0                            1       \
# eventid                            197000000001                 197000000002
# iyear                                      1970                         1970
# imonth                                        7                            0
# iday                                          2                            0
# approxdate                                  NaN                          NaN
# extended                                      0                            0
# resolution                                  NaN                          NaN
# country                                      58                          130
# country_txt                  Dominican Republic                       Mexico
# region                                        2                            1
# region_txt          Central America & Caribbean                North America
# provstate                                   NaN                          NaN
# city                              Santo Domingo                  Mexico city
# latitude                                18.4568                      19.4326
# longitude                              -69.9512                     -99.1332
# specificity                                   1                            1
# vicinity                                      0                            0
# location                                    NaN                          NaN
# summary                                     NaN                          NaN
# crit1                                         1                            1
# crit2                                         1                            1
# crit3                                         1                            1
# doubtterr                                     0                            0
# alternative                                 NaN                          NaN
# alternative_txt                             NaN                          NaN
# multiple                                      0                            0
# success                                       1                            1
# suicide                                       0                            0
# attacktype1                                   1                            6
# attacktype1_txt                   Assassination  Hostage Taking (Kidnapping)
# ...                                         ...                          ...
# propextent                                  NaN                          NaN
# propextent_txt                              NaN                          NaN
# propvalue                                   NaN                          NaN
# propcomment                                 NaN                          NaN
# ishostkid                                     0                            1
# nhostkid                                    NaN                            1
# nhostkidus                                  NaN                            0
# nhours                                      NaN                          NaN
# ndays                                       NaN                          NaN
# divert                                      NaN                          NaN
# kidhijcountry                               NaN                       Mexico
# ransom                                        0                            1
# ransomamt                                   NaN                       800000
# ransomamtus                                 NaN                          NaN
# ransompaid                                  NaN                          NaN
# ransompaidus                                NaN                          NaN
# ransomnote                                  NaN                          NaN
# hostkidoutcome                              NaN                          NaN
# hostkidoutcome_txt                          NaN                          NaN
# nreleased                                   NaN                          NaN
# addnotes                                    NaN                          NaN
# scite1                                      NaN                          NaN
# scite2                                      NaN                          NaN
# scite3                                      NaN                          NaN
# dbsource                                   PGIS                         PGIS
# INT_LOG                                       0                            0
# INT_IDEO                                      0                            1
# INT_MISC                                      0                            1
# INT_ANY                                       0                            1
# related                                     NaN                          NaN
#
#                             2                  3       \
# eventid               197001000001       197001000002
# iyear                         1970               1970
# imonth                           1                  1
# iday                             0                  0
# approxdate                     NaN                NaN
# extended                         0                  0
# resolution                     NaN                NaN
# country                        160                 78
# country_txt            Philippines             Greece
# region                           5                  8
# region_txt          Southeast Asia     Western Europe
# provstate                   Tarlac             Attica
# city                       Unknown             Athens
# latitude                   15.4786            37.9838
# longitude                    120.6            23.7282
# specificity                      4                  1
# vicinity                         0                  0
# location                       NaN                NaN
# summary                        NaN                NaN
# crit1                            1                  1
# crit2                            1                  1
# crit3                            1                  1
# doubtterr                        0                  0
# alternative                    NaN                NaN
# alternative_txt                NaN                NaN
# multiple                         0                  0
# success                          1                  1
# suicide                          0                  0
# attacktype1                      1                  3
# attacktype1_txt      Assassination  Bombing/Explosion
# ...                            ...                ...
# propextent                     NaN                NaN
# propextent_txt                 NaN                NaN
# propvalue                      NaN                NaN
# propcomment                    NaN                NaN
# ishostkid                        0                  0
# nhostkid                       NaN                NaN
# nhostkidus                     NaN                NaN
# nhours                         NaN                NaN
# ndays                          NaN                NaN
# divert                         NaN                NaN
# kidhijcountry                  NaN                NaN
# ransom                           0                  0
# ransomamt                      NaN                NaN
# ransomamtus                    NaN                NaN
# ransompaid                     NaN                NaN
# ransompaidus                   NaN                NaN
# ransomnote                     NaN                NaN
# hostkidoutcome                 NaN                NaN
# hostkidoutcome_txt             NaN                NaN
# nreleased                      NaN                NaN
# addnotes                       NaN                NaN
# scite1                         NaN                NaN
# scite2                         NaN                NaN
# scite3                         NaN                NaN
# dbsource                      PGIS               PGIS
# INT_LOG                         -9                 -9
# INT_IDEO                        -9                 -9
# INT_MISC                         1                  1
# INT_ANY                          1                  1
# related                        NaN                NaN
#
#                                             4       \
# eventid                               197001000003
# iyear                                         1970
# imonth                                           1
# iday                                             0
# approxdate                                     NaN
# extended                                         0
# resolution                                     NaN
# country                                        101
# country_txt                                  Japan
# region                                           4
# region_txt                               East Asia
# provstate                                      NaN
# city                                       Fukouka
# latitude                                   33.5804
# longitude                                  130.396
# specificity                                      1
# vicinity                                         0
# location                                       NaN
# summary                                        NaN
# crit1                                            1
# crit2                                            1
# crit3                                            1
# doubtterr                                       -9
# alternative                                    NaN
# alternative_txt                                NaN
# multiple                                         0
# success                                          1
# suicide                                          0
# attacktype1                                      7
# attacktype1_txt     Facility/Infrastructure Attack
# ...                                            ...
# propextent                                     NaN
# propextent_txt                                 NaN
# propvalue                                      NaN
# propcomment                                    NaN
# ishostkid                                        0
# nhostkid                                       NaN
# nhostkidus                                     NaN
# nhours                                         NaN
# ndays                                          NaN
# divert                                         NaN
# kidhijcountry                                  NaN
# ransom                                           0
# ransomamt                                      NaN
# ransomamtus                                    NaN
# ransompaid                                     NaN
# ransompaidus                                   NaN
# ransomnote                                     NaN
# hostkidoutcome                                 NaN
# hostkidoutcome_txt                             NaN
# nreleased                                      NaN
# addnotes                                       NaN
# scite1                                         NaN
# scite2                                         NaN
# scite3                                         NaN
# dbsource                                      PGIS
# INT_LOG                                         -9
# INT_IDEO                                        -9
# INT_MISC                                         1
# INT_ANY                                          1
# related                                        NaN
#
#                                                                5       \
# eventid                                                  197001010002
# iyear                                                            1970
# imonth                                                              1
# iday                                                                1
# approxdate                                                        NaN
# extended                                                            0
# resolution                                                        NaN
# country                                                           217
# country_txt                                             United States
# region                                                              1
# region_txt                                              North America
# provstate                                                    Illinois
# city                                                            Cairo
# latitude                                                      37.0051
# longitude                                                    -89.1763
# specificity                                                         1
# vicinity                                                            0
# location                                                          NaN
# summary             1/1/1970: Unknown African American assailants ...
# crit1                                                               1
# crit2                                                               1
# crit3                                                               1
# doubtterr                                                           0
# alternative                                                       NaN
# alternative_txt                                                   NaN
# multiple                                                            0
# success                                                             1
# suicide                                                             0
# attacktype1                                                         2
# attacktype1_txt                                         Armed Assault
# ...                                                               ...
# propextent                                                          3
# propextent_txt                            Minor (likely < $1 million)
# propvalue                                                         NaN
# propcomment                                                       NaN
# ishostkid                                                           0
# nhostkid                                                          NaN
# nhostkidus                                                        NaN
# nhours                                                            NaN
# ndays                                                             NaN
# divert                                                            NaN
# kidhijcountry                                                     NaN
# ransom                                                              0
# ransomamt                                                         NaN
# ransomamtus                                                       NaN
# ransompaid                                                        NaN
# ransompaidus                                                      NaN
# ransomnote                                                        NaN
# hostkidoutcome                                                    NaN
# hostkidoutcome_txt                                                NaN
# nreleased                                                         NaN
# addnotes            The Cairo Chief of Police, William Petersen, r...
# scite1              "Police Chief Quits," Washington Post, January...
# scite2              "Cairo Police Chief Quits; Decries Local 'Mili...
# scite3              Christopher Hewitt, "Political Violence and Te...
# dbsource                                               Hewitt Project
# INT_LOG                                                            -9
# INT_IDEO                                                           -9
# INT_MISC                                                            0
# INT_ANY                                                            -9
# related                                                           NaN
#
#                            6       \
# eventid              197001020001
# iyear                        1970
# imonth                          1
# iday                            2
# approxdate                    NaN
# extended                        0
# resolution                    NaN
# country                       218
# country_txt               Uruguay
# region                          3
# region_txt          South America
# provstate              Montevideo
# city                   Montevideo
# latitude                 -34.8912
# longitude                -56.1872
# specificity                     1
# vicinity                        0
# location                      NaN
# summary                       NaN
# crit1                           1
# crit2                           1
# crit3                           1
# doubtterr                       0
# alternative                   NaN
# alternative_txt               NaN
# multiple                        0
# success                         0
# suicide                         0
# attacktype1                     1
# attacktype1_txt     Assassination
# ...                           ...
# propextent                    NaN
# propextent_txt                NaN
# propvalue                     NaN
# propcomment                   NaN
# ishostkid                       0
# nhostkid                      NaN
# nhostkidus                    NaN
# nhours                        NaN
# ndays                         NaN
# divert                        NaN
# kidhijcountry                 NaN
# ransom                          0
# ransomamt                     NaN
# ransomamtus                   NaN
# ransompaid                    NaN
# ransompaidus                  NaN
# ransomnote                    NaN
# hostkidoutcome                NaN
# hostkidoutcome_txt            NaN
# nreleased                     NaN
# addnotes                      NaN
# scite1                        NaN
# scite2                        NaN
# scite3                        NaN
# dbsource                     PGIS
# INT_LOG                         0
# INT_IDEO                        0
# INT_MISC                        0
# INT_ANY                         0
# related                       NaN
#
#                                                                7       \
# eventid                                                  197001020002
# iyear                                                            1970
# imonth                                                              1
# iday                                                                2
# approxdate                                                        NaN
# extended                                                            0
# resolution                                                        NaN
# country                                                           217
# country_txt                                             United States
# region                                                              1
# region_txt                                              North America
# provstate                                                  California
# city                                                          Oakland
# latitude                                                      37.8051
# longitude                                                    -122.273
# specificity                                                         1
# vicinity                                                            0
# location                                              Edes Substation
# summary             1/2/1970: Unknown perpetrators detonated explo...
# crit1                                                               1
# crit2                                                               1
# crit3                                                               1
# doubtterr                                                           1
# alternative                                                         2
# alternative_txt                                      Other Crime Type
# multiple                                                            0
# success                                                             1
# suicide                                                             0
# attacktype1                                                         3
# attacktype1_txt                                     Bombing/Explosion
# ...                                                               ...
# propextent                                                          3
# propextent_txt                            Minor (likely < $1 million)
# propvalue                                                       22500
# propcomment                          Three transformers were damaged.
# ishostkid                                                           0
# nhostkid                                                          NaN
# nhostkidus                                                        NaN
# nhours                                                            NaN
# ndays                                                             NaN
# divert                                                            NaN
# kidhijcountry                                                     NaN
# ransom                                                              0
# ransomamt                                                         NaN
# ransomamtus                                                       NaN
# ransompaid                                                        NaN
# ransompaidus                                                      NaN
# ransomnote                                                        NaN
# hostkidoutcome                                                    NaN
# hostkidoutcome_txt                                                NaN
# nreleased                                                         NaN
# addnotes            Damages were estimated to be between $20,000-$...
# scite1              Committee on Government Operations United Stat...
# scite2              Christopher Hewitt, "Political Violence and Te...
# scite3                                                            NaN
# dbsource                                               Hewitt Project
# INT_LOG                                                            -9
# INT_IDEO                                                           -9
# INT_MISC                                                            0
# INT_ANY                                                            -9
# related                                                           NaN
#
#                                                                8       \
# eventid                                                  197001020003
# iyear                                                            1970
# imonth                                                              1
# iday                                                                2
# approxdate                                                        NaN
# extended                                                            0
# resolution                                                        NaN
# country                                                           217
# country_txt                                             United States
# region                                                              1
# region_txt                                              North America
# provstate                                                   Wisconsin
# city                                                          Madison
# latitude                                                      43.0766
# longitude                                                    -89.4125
# specificity                                                         1
# vicinity                                                            0
# location                                                          NaN
# summary             1/2/1970: Karl Armstrong, a member of the New ...
# crit1                                                               1
# crit2                                                               1
# crit3                                                               1
# doubtterr                                                           0
# alternative                                                       NaN
# alternative_txt                                                   NaN
# multiple                                                            0
# success                                                             1
# suicide                                                             0
# attacktype1                                                         7
# attacktype1_txt                        Facility/Infrastructure Attack
# ...                                                               ...
# propextent                                                          3
# propextent_txt                            Minor (likely < $1 million)
# propvalue                                                       60000
# propcomment         Basketball courts, weight room, swimming pool,...
# ishostkid                                                           0
# nhostkid                                                          NaN
# nhostkidus                                                        NaN
# nhours                                                            NaN
# ndays                                                             NaN
# divert                                                            NaN
# kidhijcountry                                                     NaN
# ransom                                                              0
# ransomamt                                                         NaN
# ransomamtus                                                       NaN
# ransompaid                                                        NaN
# ransompaidus                                                      NaN
# ransomnote                                                        NaN
# hostkidoutcome                                                    NaN
# hostkidoutcome_txt                                                NaN
# nreleased                                                         NaN
# addnotes            The New Years Gang issue a communiqué to a loc...
# scite1              Tom Bates, "Rads: The 1970 Bombing of the Army...
# scite2              David Newman, Sandra Sutherland, and Jon Stewa...
# scite3              The Wisconsin Cartographers' Guild, "Wisconsin...
# dbsource                                               Hewitt Project
# INT_LOG                                                             0
# INT_IDEO                                                            0
# INT_MISC                                                            0
# INT_ANY                                                             0
# related                                                           NaN
#
#                                                                9       \
# eventid                                                  197001030001
# iyear                                                            1970
# imonth                                                              1
# iday                                                                3
# approxdate                                                        NaN
# extended                                                            0
# resolution                                                        NaN
# country                                                           217
# country_txt                                             United States
# region                                                              1
# region_txt                                              North America
# provstate                                                   Wisconsin
# city                                                          Madison
# latitude                                                      43.0729
# longitude                                                    -89.3867
# specificity                                                         1
# vicinity                                                            0
# location                                                          NaN
# summary             1/3/1970: Karl Armstrong, a member of the New ...
# crit1                                                               1
# crit2                                                               1
# crit3                                                               1
# doubtterr                                                           0
# alternative                                                       NaN
# alternative_txt                                                   NaN
# multiple                                                            0
# success                                                             1
# suicide                                                             0
# attacktype1                                                         7
# attacktype1_txt                        Facility/Infrastructure Attack
# ...                                                               ...
# propextent                                                          3
# propextent_txt                            Minor (likely < $1 million)
# propvalue                                                         NaN
# propcomment                                             Slight damage
# ishostkid                                                           0
# nhostkid                                                          NaN
# nhostkidus                                                        NaN
# nhours                                                            NaN
# ndays                                                             NaN
# divert                                                            NaN
# kidhijcountry                                                     NaN
# ransom                                                              0
# ransomamt                                                         NaN
# ransomamtus                                                       NaN
# ransompaid                                                        NaN
# ransompaidus                                                      NaN
# ransomnote                                                        NaN
# hostkidoutcome                                                    NaN
# hostkidoutcome_txt                                                NaN
# nreleased                                                         NaN
# addnotes            Karl Armstrong's girlfriend, Lynn Schultz, dro...
# scite1              Committee on Government Operations United Stat...
# scite2              Tom Bates, "Rads: The 1970 Bombing of the Army...
# scite3              David Newman, Sandra Sutherland, and Jon Stewa...
# dbsource                                               Hewitt Project
# INT_LOG                                                             0
# INT_IDEO                                                            0
# INT_MISC                                                            0
# INT_ANY                                                             0
# related                                                           NaN
#
#                                           ...                          \
# eventid                                   ...
# iyear                                     ...
# imonth                                    ...
# iday                                      ...
# approxdate                                ...
# extended                                  ...
# resolution                                ...
# country                                   ...
# country_txt                               ...
# region                                    ...
# region_txt                                ...
# provstate                                 ...
# city                                      ...
# latitude                                  ...
# longitude                                 ...
# specificity                               ...
# vicinity                                  ...
# location                                  ...
# summary                                   ...
# crit1                                     ...
# crit2                                     ...
# crit3                                     ...
# doubtterr                                 ...
# alternative                               ...
# alternative_txt                           ...
# multiple                                  ...
# success                                   ...
# suicide                                   ...
# attacktype1                               ...
# attacktype1_txt                           ...
# ...                                       ...
# propextent                                ...
# propextent_txt                            ...
# propvalue                                 ...
# propcomment                               ...
# ishostkid                                 ...
# nhostkid                                  ...
# nhostkidus                                ...
# nhours                                    ...
# ndays                                     ...
# divert                                    ...
# kidhijcountry                             ...
# ransom                                    ...
# ransomamt                                 ...
# ransomamtus                               ...
# ransompaid                                ...
# ransompaidus                              ...
# ransomnote                                ...
# hostkidoutcome                            ...
# hostkidoutcome_txt                        ...
# nreleased                                 ...
# addnotes                                  ...
# scite1                                    ...
# scite2                                    ...
# scite3                                    ...
# dbsource                                  ...
# INT_LOG                                   ...
# INT_IDEO                                  ...
# INT_MISC                                  ...
# INT_ANY                                   ...
# related                                   ...
#
#                                                                170340  \
# eventid                                                  201612310035
# iyear                                                            2016
# imonth                                                             12
# iday                                                               31
# approxdate                                                        NaN
# extended                                                            0
# resolution                                                        NaN
# country                                                             4
# country_txt                                               Afghanistan
# region                                                              6
# region_txt                                                 South Asia
# provstate                                                     Jawzjan
# city                                                          Jakdalk
# latitude                                                       36.668
# longitude                                                     65.7511
# specificity                                                         2
# vicinity                                                            1
# location                   The incident occurred in Jakdalk district.
# summary             12/31/2016: Assailants attacked a security pos...
# crit1                                                               1
# crit2                                                               1
# crit3                                                               0
# doubtterr                                                           1
# alternative                                                         1
# alternative_txt                            Insurgency/Guerilla Action
# multiple                                                            1
# success                                                             0
# suicide                                                             0
# attacktype1                                                         9
# attacktype1_txt                                               Unknown
# ...                                                               ...
# propextent                                                        NaN
# propextent_txt                                                    NaN
# propvalue                                                         NaN
# propcomment                                                       NaN
# ishostkid                                                           0
# nhostkid                                                          NaN
# nhostkidus                                                        NaN
# nhours                                                            NaN
# ndays                                                             NaN
# divert                                                            NaN
# kidhijcountry                                                     NaN
# ransom                                                            NaN
# ransomamt                                                         NaN
# ransomamtus                                                       NaN
# ransompaid                                                        NaN
# ransompaidus                                                      NaN
# ransomnote                                                        NaN
# hostkidoutcome                                                    NaN
# hostkidoutcome_txt                                                NaN
# nreleased                                                         NaN
# addnotes            Casualty figures represent a division of the t...
# scite1              "Jawzjan clash leaves 2 rebels dead, 8 wounded...
# scite2                                                            NaN
# scite3                                                            NaN
# dbsource                                     START Primary Collection
# INT_LOG                                                             0
# INT_IDEO                                                            0
# INT_MISC                                                            0
# INT_ANY                                                             0
# related             201612310034, 201612310035, 201612310036, 2016...
#
#                                                                170341  \
# eventid                                                  201612310036
# iyear                                                            2016
# imonth                                                             12
# iday                                                               31
# approxdate                                                        NaN
# extended                                                            0
# resolution                                                        NaN
# country                                                             4
# country_txt                                               Afghanistan
# region                                                              6
# region_txt                                                 South Asia
# provstate                                                     Jawzjan
# city                                                         Shirkhel
# latitude                                                      36.6662
# longitude                                                     65.7548
# specificity                                                         2
# vicinity                                                            0
# location                The incident occurred in Shibirghan district.
# summary             12/31/2016: Assailants attacked a security pos...
# crit1                                                               1
# crit2                                                               1
# crit3                                                               0
# doubtterr                                                           1
# alternative                                                         1
# alternative_txt                            Insurgency/Guerilla Action
# multiple                                                            1
# success                                                             0
# suicide                                                             0
# attacktype1                                                         9
# attacktype1_txt                                               Unknown
# ...                                                               ...
# propextent                                                        NaN
# propextent_txt                                                    NaN
# propvalue                                                         NaN
# propcomment                                                       NaN
# ishostkid                                                           0
# nhostkid                                                          NaN
# nhostkidus                                                        NaN
# nhours                                                            NaN
# ndays                                                             NaN
# divert                                                            NaN
# kidhijcountry                                                     NaN
# ransom                                                            NaN
# ransomamt                                                         NaN
# ransomamtus                                                       NaN
# ransompaid                                                        NaN
# ransompaidus                                                      NaN
# ransomnote                                                        NaN
# hostkidoutcome                                                    NaN
# hostkidoutcome_txt                                                NaN
# nreleased                                                         NaN
# addnotes            Casualty figures represent a division of the t...
# scite1              "Jawzjan clash leaves 2 rebels dead, 8 wounded...
# scite2                                                            NaN
# scite3                                                            NaN
# dbsource                                     START Primary Collection
# INT_LOG                                                             0
# INT_IDEO                                                            0
# INT_MISC                                                            0
# INT_ANY                                                             0
# related             201612310034, 201612310035, 201612310036, 2016...
#
#                                                                170342  \
# eventid                                                  201612310037
# iyear                                                            2016
# imonth                                                             12
# iday                                                               31
# approxdate                                                        NaN
# extended                                                            0
# resolution                                                        NaN
# country                                                             4
# country_txt                                               Afghanistan
# region                                                              6
# region_txt                                                 South Asia
# provstate                                                     Jawzjan
# city                                                            Tofan
# latitude                                                      36.6597
# longitude                                                     65.7524
# specificity                                                         2
# vicinity                                                            0
# location                The incident occurred in Shibirghan district.
# summary             12/31/2016: Assailants attacked a security pos...
# crit1                                                               1
# crit2                                                               1
# crit3                                                               0
# doubtterr                                                           1
# alternative                                                         1
# alternative_txt                            Insurgency/Guerilla Action
# multiple                                                            1
# success                                                             0
# suicide                                                             0
# ...
# attacktype1                                                         3
# attacktype1_txt                                     Bombing/Explosion
# ...                                                               ...
# propextent                                                        NaN
# propextent_txt                                                    NaN
# propvalue                                                         NaN
# propcomment                                                       NaN
# ishostkid                                                           0
# nhostkid                                                          NaN
# nhostkidus                                                        NaN
# nhours                                                            NaN
# ndays                                                             NaN
# divert                                                            NaN
# kidhijcountry                                                     NaN
# ransom                                                            NaN
# ransomamt                                                         NaN
# ransomamtus                                                       NaN
# ransompaid                                                        NaN
# ransompaidus                                                      NaN
# ransomnote                                                        NaN
# hostkidoutcome                                                    NaN
# hostkidoutcome_txt                                                NaN
# nreleased                                                         NaN
# addnotes                                                          NaN
# scite1              "AFP braces for more BIFF attacks in ARMM," Ma...
# scite2              "Asia: US Army ASD Philippine Terrorist Media ...
# scite3                                                            NaN
# dbsource                                     START Primary Collection
# INT_LOG                                                            -9
# INT_IDEO                                                           -9
# INT_MISC                                                            0
# INT_ANY                                                            -9
# related                                                           NaN
#
#                                                                170347  \
# eventid                                                  201612310043
# iyear                                                            2016
# imonth                                                             12
# iday                                                               31
# approxdate                                                        NaN
# extended                                                            1
# resolution                                                        NaN
# country                                                           229
# country_txt                          Democratic Republic of the Congo
# region                                                             11
# region_txt                                         Sub-Saharan Africa
# provstate                                                    Bas-Uele
# city                                                       Nakolongbo
# latitude                                                      4.30861
# longitude                                                     25.0914
# specificity                                                         2
# vicinity                                                            0
# location                                                          NaN
# summary             12/31/2016: Assailants attacked a village and ...
# crit1                                                               1
# crit2                                                               1
# crit3                                                               1
# doubtterr                                                           0
# alternative                                                       NaN
# alternative_txt                                                   NaN
# multiple                                                            0
# success                                                             1
# suicide                                                             0
# attacktype1                                                         6
# attacktype1_txt                           Hostage Taking (Kidnapping)
# ...                                                               ...
# propextent                                                        NaN
# propextent_txt                                                    NaN
# propvalue                                                         NaN
# propcomment                                                       NaN
# ishostkid                                                           1
# nhostkid                                                           33
# nhostkidus                                                          0
# nhours                                                            NaN
# ndays                                                               8
# divert                                                            NaN
# kidhijcountry                                                     NaN
# ransom                                                              0
# ransomamt                                                         NaN
# ransomamtus                                                       NaN
# ransompaid                                                        NaN
# ransompaidus                                                      NaN
# ransomnote                                                        NaN
# hostkidoutcome                                                      5
# hostkidoutcome_txt                                  Successful Rescue
# nreleased                                                          33
# addnotes                                                          NaN
# scite1              "DRC Armed Forces Dislodge Ugandan LRA Rebels ...
# scite2                                                            NaN
# scite3                                                            NaN
# dbsource                                     START Primary Collection
# INT_LOG                                                             1
# INT_IDEO                                                            1
# INT_MISC                                                            0
# INT_ANY                                                             1
# related                                                           NaN
#
#                                                                170348  \
# eventid                                                  201612310044
# iyear                                                            2016
# imonth                                                             12
# iday                                                               31
# approxdate                                                        NaN
# extended                                                            0
# resolution                                                        NaN
# country                                                           130
# country_txt                                                    Mexico
# region                                                              1
# region_txt                                              North America
# provstate                                                   Chihuahua
# city                                                        Guachochi
# latitude                                                      26.8196
# longitude                                                     -107.07
# specificity                                                         1
# vicinity                                                            0
# location                                                          NaN
# summary             12/31/2016: Assailants opened fire on the hous...
# crit1                                                               0
# crit2                                                               1
# crit3                                                               1
# doubtterr                                                           1
# alternative                                                         2
# alternative_txt                                      Other Crime Type
# multiple                                                            0
# success                                                             0
# suicide                                                             0
# attacktype1                                                         1
# attacktype1_txt                                         Assassination
# ...                                                               ...
# propextent                                                          3
# propextent_txt                            Minor (likely < $1 million)
# propvalue                                                         -99
# propcomment                       A house was damaged in this attack.
# ishostkid                                                           0
# nhostkid                                                          NaN
# nhostkidus                                                        NaN
# nhours                                                            NaN
# ndays                                                             NaN
# divert                                                            NaN
# kidhijcountry                                                     NaN
# ransom                                                            NaN
# ransomamt                                                         NaN
# ransomamtus                                                       NaN
# ransompaid                                                        NaN
# ransompaidus                                                      NaN
# ransomnote                                                        NaN
# hostkidoutcome                                                    NaN
# hostkidoutcome_txt                                                NaN
# nreleased                                                         NaN
# addnotes            There is doubt that this incident meets terror...
# scite1              "Gunmen shoot at home of Mexican indigenous ri...
# scite2              " Gunmen shoot at home of Mexican indigenous ...
# scite3                                                            NaN
# dbsource                                     START Primary Collection
# INT_LOG                                                            -9
# INT_IDEO                                                           -9
# INT_MISC                                                            0
# INT_ANY                                                            -9
# related                                                           NaN
#
#                                                                170349
# eventid                                                  201701270001
# iyear                                                            2016
# imonth                                                             12
# iday                                                               30
# approxdate                                                        NaN
# extended                                                            0
# resolution                                                        NaN
# country                                                           195
# country_txt                                                     Sudan
# region                                                             11
# region_txt                                         Sub-Saharan Africa
# provstate                                              Central Darfur
# city                                                          Nertiti
# latitude                                                      12.9614
# longitude                                                     24.0441
# specificity                                                         1
# vicinity                                                            0
# location                                                          NaN
# summary             12/30/2016: Assailants armed with firearms att...
# crit1                                                               1
# crit2                                                               1
# crit3                                                               1
# doubtterr                                                           1
# alternative                                                         5
# alternative_txt                                          State Actors
# multiple                                                            0
# success                                                             0
# suicide                                                             0
# attacktype1                                                         2
# attacktype1_txt                                         Armed Assault
# ...                                                               ...
# propextent                                                        NaN
# propextent_txt                                                    NaN
# propvalue                                                         NaN
# propcomment                                                       NaN
# ishostkid                                                           0
# nhostkid                                                          NaN
# nhostkidus                                                        NaN
# nhours                                                            NaN
# ndays                                                             NaN
# divert                                                            NaN
# kidhijcountry                                                     NaN
# ransom                                                            NaN
# ransomamt                                                         NaN
# ransomamtus                                                       NaN
# ransompaid                                                        NaN
# ransompaidus                                                      NaN
# ransomnote                                                        NaN
# hostkidoutcome                                                    NaN
# hostkidoutcome_txt                                                NaN
# nreleased                                                         NaN
# addnotes            There is doubt that this incident meets terror...
# scite1              "Rebels To Blame For Nierteti Killing: Central...
# scite2              "Security deteriorates in West Darfur alongsid...
# scite3                                                            NaN
# dbsource                                     START Primary Collection
# INT_LOG                                                             0
# INT_IDEO                                                            0
# INT_MISC                                                            0
# INT_ANY                                                             0
# related                                                           NaN
#
# [135 rows x 170350 columns]

# %%
df.shape
# Out:
# (170350, 135)

# %%
df['related'][df['related'].notnull()].shape
# Out:
# (22845,)

# %%
len(set(df['gname']))
# Out:
# 3454

# %%
[x for x in df['gname'] if x.startswith("Boko")]
# Out:
# ['Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  'Boko Haram',
#  ...]
