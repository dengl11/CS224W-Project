# %% [markdown]
# # Community Constructor

# %%
""" Style """
import warnings
warnings.filterwarnings("ignore")  # suppres all warnings
from plotly.offline import iplot, init_notebook_mode
init_notebook_mode(connected=True)
""" Autoload """
# %load_ext autoreload
# %autoreload 2
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
""" Backend """
from community_constructor_backend import *
# Out:
# Data Imported: (6575, 134)
# Shape Updated from (6575, 134) -> (83, 134) | 6492 Rows Removed.

# %%
iplot(fig)
# Out:
# <div id="16b3b1a5-94e0-40ac-9191-ed2c46c356f2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("16b3b1a5-94e0-40ac-9191-ed2c46c356f2", [{"name": "event", "hoverinfo": "text", "type": "scatter", "marker": {"color": [150, 32, 28, 31, 101, 39, 36, 30, 35, 41, 30, 32, 37, 28, 60, 35, 31, 32, 40, 32, 42, 53, 82, 82, 40, 29, 70, 40, 31, 43, 48, 37, 47, 50, 35, 41, 40, 40, 50, 45, 58, 42, 31, 29, 38, 30, 36, 74, 240, 100, 32, 32, 30, 33, 30, 30, 73, 45, 54, 42, 71, 45, 30, 50, 73, 67, 31, 42, 68, 30, 34, 85, 39, 38, 38, 38, 38, 28, 29, 154, 90, 30, 35], "reversescale": true, "line": {"width": 2}, "colorbar": {"thickness": 15, "xanchor": "left", "title": "N-kill"}, "size": 10, "showscale": true, "colorscale": "YIGnBu"}, "y": [34.733333, 32.050438, 31.816667, 34.533056, 31.617667, 31.008056, 31.617667, 31.62
# ...
